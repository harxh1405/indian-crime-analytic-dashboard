# %%
import pandas as pd

# %%
df16=pd.read_csv('crime16.csv')
df17=pd.read_csv('crime17.csv')
df18=pd.read_csv('crime18.csv')
df19=pd.read_csv('crime19.csv')
df20=pd.read_csv('crime20.csv')
df21=pd.read_csv('crime21.csv')

# %%
# df16.drop('Category (Col.2)',axis=1,inplace=True)
df16.head(2)
df16.shape
# Out:
# (38, 19)

# %%
# df17=df17.drop(columns=['Category (Col.2)','S. No (Col.1)']).reset_index(drop=True)
# df17['year']=2017
df17
# df17.head(2)
# df17.shape
# Out:
#     S. No (Col.1)                   Category (Col.2)  \
# 0               1  Offences Affecting the Human Body
# 1               2  Offences Affecting the Human Body
# 2               3  Offences Affecting the Human Body
# 3             3.1  Offences Affecting the Human Body
# 4           3.1.1  Offences Affecting the Human Body
# ..            ...                                ...
# 138            53           Miscellaneous IPC Crimes
# 139            54           Miscellaneous IPC Crimes
# 140         Total           Miscellaneous IPC Crimes
# 141            55                   Other IPC Crimes
# 142   Grand Total        Total Cognizable IPC Crimes
#
#                                     Crime Head (Col.3)  \
# 0                                               Murder
# 1            Culpable Homicide not amounting to Murder
# 2                  Causing Death by Negligence - Total
# 3    Deaths due to Negligence relating to Road Acci...
# ...

# %%
df17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 25 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   S. No (Col.1)                                                                          143 non-null    object
#  1   Category (Col.2)                                                                       143 non-null    object
#  2   Crime Head (Col.3)                                                                     143 non-null    object
#  3   Cases Pending Investigation from Previous Year (Col.4)                                 143 non-null    int64
#  4   Cases Reported during the year (Col.5)                                                 143 non-null    int64
# ...

# %%
df17 = df17.rename(columns={
    "Crime Head (Col.3)": "crime_head",
    "Cases Pending Investigation from Previous Year (Col.4)": "pending_prev",
    "Cases Reported during the year (Col.5)": "reported_year",
    "Cases Reopened for Investigation (Col.6)": "reopened",
    "Total Cases for Investigation (Col.7=Col.4+ Col.5+ Col.6) (Col.7)": "total_investigation_reported",

    "Cases Not Investigated under 157_1_b CRPC (Col.8)": "not_investigated",
    "Cases Transferred to other State or Agency (Col.9)": "transferred",
    "Cases Withdrawn by the Govt during Investigation (Col.10)": "withdrawn",

    "Final Report - Cases Ended as FR Non Cognizable (Col.11)": "fr_non_cognizable",
    "Final Report - Cases Ended as Final Report False (Col.12)": "fr_false",
    "Final Report - Cases Ended as Mistake of Fact or of Law or Civil Dispute (Col.13)": "fr_mistake_civil",
    "Final Report - Cases True but Insufficient Evidence or Untraced or No Clue (Col.14)": "fr_untraced",
    "Final Report - Cases Abated during Investigation (Col.15)": "fr_abated",
    "Final Report - Total (Col.16=Col.11+ Col.12+ Col.13+ Col.14+ Col.15)": "fr_total",

    "Chargesheets Submitted - Cases Chargesheeted Out of Cases from Previous Year (Col.17)": "chargesheet_prev",
    "Chargesheets Submitted - Cases Chargesheeted Out of Cases during the Year (Col.18)": "chargesheet_current",
    "Chargesheets Submitted - Cases Chargesheeted (Col.19=Col.17+ Col.18)": "chargesheet_total",

    "Total Cases Disposed Off by Police (Col.20=Col.8+ Col.9+ Col.16+ Col.19)": "disposed_total",

    "Cases Quashed at Investigation Stage (Col.21)": "quashed",
    "Cases Stayed at Investigation Stage (Col.22)": "stayed",

    "Cases Pending Investigation at End of the Year (Col.23=Col.7- Col.10- Col.20- Col.21)": "pending_end",

    "Chargesheeting Rate (Col.24=Col.19/ Col.20) *100": "chargesheet_rate_reported",
    "Pendency Percentage (Col.25=Col.23/ Col.7) *100": "pendency_pct_reported"
})
df17.head(2)
# Out:
#   S. No (Col.1)                   Category (Col.2)  \
# 0             1  Offences Affecting the Human Body
# 1             2  Offences Affecting the Human Body
#
#                                   crime_head  pending_prev  reported_year  \
# 0                                     Murder         22590          28653
# 1  Culpable Homicide not amounting to Murder          1773           3401
#
#    reopened  total_investigation_reported  not_investigated  transferred  \
# 0        36                         51279                 1          117
# 1        24                          5198                 0            1
#
#    withdrawn  ...  fr_total  chargesheet_prev  chargesheet_current  \
# 0          1  ...      4278              9186                16809
# 1          1  ...       516              1050                 1881
#
#    chargesheet_total  disposed_total  quashed  stayed  pending_end  \
# 0              25995           30391        2     125        20885
# ...

# %%
 
violent_crimes_2017 = {
    "Murder": "Violent Crime",
    "Culpable Homicide not amounting to Murder": "Violent Crime",
    "Causing Death by Negligence - Total": "Violent Crime",
    "Deaths due to Negligence relating to Road Accidents": "Violent Crime",
    "Hit and Run": "Violent Crime",
    "Other Accidents": "Violent Crime",
    "Deaths due to Negligence relating to Rail Accidents": "Violent Crime",
    "Deaths due to Medical Negligence": "Violent Crime",
    "Deaths due to Negligence of Civic Bodies": "Violent Crime",
    "Deaths due to other Negligence": "Violent Crime",
    "Abetment of Suicide": "Violent Crime",
    "Attempt to Commit Murder": "Violent Crime",
    "Attempt to commit Culpable Homicide": "Violent Crime",
    "Attempt to Commit Suicide": "Violent Crime",
    "Hurt - Total": "Violent Crime",
    "Simple Hurt": "Violent Crime",
    "Voluntarily Causing Simple Hurt": "Violent Crime",
    "Voluntarily causing hurt by Dangerous weapons or means": "Violent Crime",
    "Voluntarily Causing hurt/Force to deter public servant from his duty": "Violent Crime",
    "Causing Hurt by act endangering life/safety of others": "Violent Crime",
    "Other Simple Hurt": "Violent Crime",
    "Grievous Hurt": "Violent Crime",
    "Voluntarily causing grievous hurt": "Violent Crime",
    "Voluntarily causing grievous hurt by dangerous weapons or means": "Violent Crime",
    "Voluntarily Causing Grievous hurt/Force to deter public servant from his duty": "Violent Crime",
    "Causing Grievous Hurt by act endangering life/safety of others": "Violent Crime",
    "Other Grievous Hurt": "Violent Crime",
    "Acid Attack": "Violent Crime",
    "Attempt to Acid Attack": "Violent Crime",
    "Unnatural Offences": "Violent Crime",
    "Offences Affecting the Human Body (Total)": "Violent Crime"
}
property_crimes_2017 = {
    "Theft": "Property Crime",
    "Auto/Motor Vehicle Theft": "Property Crime",
    "Other Thefts": "Property Crime",
    "Burglary": "Property Crime",
    "Day Time": "Property Crime",
    "Night": "Property Crime",
    "Extortion & Blackmailing": "Property Crime",
    "Robbery": "Property Crime",
    "Attempt to Commit Dacoity/Robbery": "Property Crime",
    "Dacoity": "Property Crime",
    "Dacoity with Murder": "Property Crime",
    "Making Preparation and Assembly for committing Dacoity": "Property Crime",
    "Criminal Misappropriation": "Property Crime",
    "Criminal Breach of Trust": "Property Crime",
    "Dishonestly Receiving/Dealing-in Stolen Property": "Property Crime",
    "Criminal Trespass": "Property Crime",
    "Arson": "Property Crime",
    "Offences against Property (Total)": "Property Crime"
}

# %%
economic_crimes_2017 = {
    "Counterfeiting": "Economic / Financial Crime",
    "Counterfeit Coin": "Economic / Financial Crime",
    "Counterfeiting Government Stamp": "Economic / Financial Crime",
    "Counterfeiting of Seal or Mark": "Economic / Financial Crime",
    "Counterfeit Currency & Bank notes": "Economic / Financial Crime",
    "Forgery, Cheating & Fraud": "Economic / Financial Crime",
    "Fraud": "Economic / Financial Crime",
    "Bank": "Economic / Financial Crime",
    "ATMs": "Economic / Financial Crime",
    "Credit Card/Debit Card": "Economic / Financial Crime",
    "Other Frauds": "Economic / Financial Crime",
    "Other Cheating": "Economic / Financial Crime",
    "Other Forgery": "Economic / Financial Crime",
    "Cheating by Impersonation": "Economic / Financial Crime",
    "Offences Relating to Documents & Property Marks (Total)": "Economic / Financial Crime"
}
public_order_state_crimes_2017 = {
    "Offences against State": "Public Order & State Crime",
    "Sedition": "Public Order & State Crime",
    "Offences against the State (Total)": "Public Order & State Crime",
    "Unlawful Assembly": "Public Order & State Crime",
    "Riots": "Public Order & State Crime",
    "Communal/Religious": "Public Order & State Crime",
    "Sectarian": "Public Order & State Crime",
    "Industrial": "Public Order & State Crime",
    "Political": "Public Order & State Crime",
    "Caste Conflict": "Public Order & State Crime",
    "Agrarian": "Public Order & State Crime",
    "Students": "Public Order & State Crime",
    "Vigilants": "Public Order & State Crime",
    "Money Dispute": "Public Order & State Crime",
    "Water Dispute": "Public Order & State Crime",
    "Land/Property Dispute": "Public Order & State Crime",
    "Family Disputes": "Public Order & State Crime",
    "Enmity/Rivalry": "Public Order & State Crime",
    "Electricity/Power Supply Disputes": "Public Order & State Crime",
    "Rioting while in Aandolan/Morcha": "Public Order & State Crime",
    "Rioting/Attacks on Police Personnel or Govt Servants": "Public Order & State Crime",
    "Other Riots": "Public Order & State Crime",
    "Offences promoting enmity between different groups": "Public Order & State Crime",
    "Promoting enmity between groups": "Public Order & State Crime",
    "Imputation, assertions prejudicial to national integration": "Public Order & State Crime",
    "Affray": "Public Order & State Crime",
    "Offences against Public Tranquillity (Total)": "Public Order & State Crime",
    "Offences relating to Elections": "Public Order & State Crime",
    "Disobedience to order duly promulgated by Public Servant": "Public Order & State Crime",
    "Harbouring an Offender": "Public Order & State Crime",
    "Offences relating to Religion": "Public Order & State Crime"
}

# %%
crimes_against_women_2017 = {
    "Dowry Deaths": "Crime Against Women",
    "Assault on Women with Intent to Outrage her Modesty - Total": "Crime Against Women",
    "Assault on Women with Intent to Outrage her Modesty": "Crime Against Women",
    "Sexual Harassment": "Crime Against Women",
    "at Work or Office Premises": "Crime Against Women",
    "In Public Transport System": "Crime Against Women",
    "In Shelter Homes for women and Children": "Crime Against Women",
    "Other Places": "Crime Against Women",
    "Assault or use of Criminal Force on women with intent to Disrobe": "Crime Against Women",
    "Voyeurism": "Crime Against Women",
    "Stalking": "Crime Against Women",
    "Rape": "Crime Against Women",
    "Attempt to Commit Rape": "Crime Against Women",
    "Cruelty by Husband or his Relatives": "Crime Against Women",
    "Insult to the Modesty of Women": "Crime Against Women"
}
crimes_against_children_2017 = {
    "Miscarriage, Infanticide, Foeticide and Abandonment": "Crime Against Children",
    "Procuration of Minor Girls": "Crime Against Children",
    "Selling of Minors for Prostitution": "Crime Against Children",
    "Buying of Minors for Prostitution": "Crime Against Children",
    "Missing Children Deemed as Kidnapped": "Crime Against Children"
}

# %%
miscellaneous_crimes_2017 = {
    "Human Trafficking": "Miscellaneous / Other Crime",
    "Exploitation of Trafficked Person": "Miscellaneous / Other Crime",
    "Offences relating to Adulteration or Sale of Food/Drugs": "Miscellaneous / Other Crime",
    "Rash Driving on Public way": "Miscellaneous / Other Crime",
    "Rash Driving on Public Way": "Miscellaneous / Other Crime",
    "Causing Hurt by Rash/Negligent Driving on Public Way": "Miscellaneous / Other Crime",
    "Causing Grievous Hurt by Rash/Negligent Driving on Public": "Miscellaneous / Other Crime",
    "Obstruction on Public way": "Miscellaneous / Other Crime",
    "Sale of obscene Books/Objects": "Miscellaneous / Other Crime",
    "Obscene Acts and Songs at Public Places": "Miscellaneous / Other Crime",
    "Offences related to Mischief": "Miscellaneous / Other Crime",
    "Circulate False/Fake News/Rumours": "Miscellaneous / Other Crime",
    "Criminal Intimidation": "Miscellaneous / Other Crime",
    "Miscellaneous IPC Crimes (Total)": "Miscellaneous / Other Crime",
    "Other IPC Crimes": "Miscellaneous / Other Crime",
    "Total Cognizable IPC Crimes": "Miscellaneous / Other Crime"
}

# %%
crime_type_map = {
    **violent_crimes_2017,
    **property_crimes_2017,
    **economic_crimes_2017,
    **public_order_state_crimes_2017,
    **crimes_against_women_2017,
    **crimes_against_children_2017,
    **miscellaneous_crimes_2017
}

df17["crime_type"] = df17["crime_head"].map(crime_type_map)
df17.head(2)
# Out:
#   S. No (Col.1)                   Category (Col.2)  \
# 0             1  Offences Affecting the Human Body
# 1             2  Offences Affecting the Human Body
#
#                                   crime_head  pending_prev  reported_year  \
# 0                                     Murder         22590          28653
# 1  Culpable Homicide not amounting to Murder          1773           3401
#
#    reopened  total_investigation_reported  not_investigated  transferred  \
# 0        36                         51279                 1          117
# 1        24                          5198                 0            1
#
#    withdrawn  ...  chargesheet_prev  chargesheet_current  chargesheet_total  \
# 0          1  ...              9186                16809              25995
# 1          1  ...              1050                 1881               2931
#
#    disposed_total  quashed  stayed  pending_end  chargesheet_rate_reported  \
# ...

# %%
df17[df17['crime_type'].isnull()]
# Out:
#    S. No (Col.1)                   Category (Col.2)  \
# 31            11  Offences Affecting the Human Body
# 42            13  Offences Affecting the Human Body
# 43          13.1  Offences Affecting the Human Body
# 45        13.1.2  Offences Affecting the Human Body
# 46          13.2  Offences Affecting the Human Body
# 47          13.3  Offences Affecting the Human Body
# 48          13.4  Offences Affecting the Human Body
# 49          13.5  Offences Affecting the Human Body
# 51          13.7  Offences Affecting the Human Body
# 52          13.8  Offences Affecting the Human Body
# 63          21.2             Offences against State
#
#                                            crime_head  pending_prev  \
# 31                     Wrongful Restraint/Confinement          3897
# 42                   Kidnapping and Abduction - Total         57598
# 43                           Kidnapping and Abduction         23238
# ...

# %%
violent_crimes_2017.update({
    "Wrongful Restraint/Confinement": "Violent Crime",
    "Kidnapping and Abduction - Total": "Violent Crime",
    "Kidnapping and Abduction": "Violent Crime",
    "Other Kidnapping & Abduction": "Violent Crime",
    "Kidnapping and Abduction for the Purpose of Begging": "Violent Crime",
    "Kidnapping and Abduction in order to Murder": "Violent Crime",
    "Kidnapping for Ransom": "Violent Crime"
})
crimes_against_women_2017.update({
    "Kidnapping and Abduction of Women to compel her for marriage": "Crime Against Women"
})
crimes_against_children_2017.update({
    "Importation of Girls from Foreign Country": "Crime Against Children"
})
miscellaneous_crimes_2017.update({
    "Others": "Miscellaneous / Other Crime"
})

# %%
crime_type_map = {
    **violent_crimes_2017,
    **property_crimes_2017,
    **economic_crimes_2017,
    **public_order_state_crimes_2017,
    **crimes_against_women_2017,
    **crimes_against_children_2017,
    **miscellaneous_crimes_2017
}

# %%
df17[df17["crime_head"].map(crime_type_map).isna()]["crime_head"].unique()
# df17.head(5)
# Out:
# array([], dtype=object)

# %%
# df18=df18.drop(columns=['Category (Col.2)','S. No (Col.1)']).reset_index(drop=True)
# df18['year']=2018

# df18.drop('Category (Col.2)',axis=1,inplace=True)
df18.head(2)
# df18.shape
# Out:
#   S. No (Col.1)                   Category (Col.2)  \
# 0             1  Offences Affecting the Human Body
# 1             2  Offences Affecting the Human Body
#
#                           Crime Head (Col.3)  \
# 0                                     Murder
# 1  Culpable Homicide not amounting to Murder
#
#    Cases Pending Investigation from Previous Year (Col.4)  \
# 0                                              20839
# 1                                               1745
#
#    Cases Reported during the year (Col.5)  \
# 0                                   29017
# 1                                    3635
#
#    Cases Reopened for Investigation (Col.6)  \
# 0                                        35
# 1                                         2
#
#    Total Cases for Investigation (Col.7=Col.4+ Col.5+ Col.6)  \
# 0                                              49891
# 1                                               5382
#
# ...

# %%
ipc_2018_rename_map = {

    # Dimensions
    "Crime Head (Col.3)": "crime_head",

    # Case inflow
    "Cases Pending Investigation from Previous Year (Col.4)": "pending_prev",
    "Cases Reported during the year (Col.5)": "reported_year",
    "Cases Reopened for Investigation (Col.6)": "reopened",
    "Total Cases for Investigation (Col.7=Col.4+ Col.5+ Col.6)": "total_investigation_reported",

    # Investigation actions
    "Cases Not Investigated under 157_1_b CRPC (Col.8)": "not_investigated",
    "Cases Transferred to other State or Agency (Col.9)": "transferred",
    "Cases Withdrawn by the Govt during Investigation (Col.10)": "withdrawn",

    # Final report breakup
    "Final Report - Cases Ended as FR Non Cognizable (Col.11)": "fr_non_cognizable",
    "Final Report - Cases Ended as Final Report False (Col.12)": "fr_false",
    "Final Report - Cases Ended as Mistake of Fact or of Law or Civil Dispute (Col.13)": "fr_mistake_civil",
    "Final Report - Cases True but Insufficient Evidence or Untraced or No Clue (Col.14)": "fr_untraced",
    "Final Report - Cases Abated during Investigation (Col.15)": "fr_abated",
    "Final Report - Total (Col.16=Col.11+ Col.12+ Col.13+ Col.14+ Col.15)": "fr_total",

    # Chargesheeting
    "Chargesheets Submitted - Cases Chargsheeted Out of Cases from Previous Year (Col.17)": "chargesheet_prev",
    "Chargesheets Submitted - Cases Chargesheeted Out of Cases during the Year (Col.18)": "chargesheet_current",
    "Chargesheets Submitted - Cases Chargesheeted (Col.19=Col.17+ Col.18)": "chargesheet_total",

    # Disposal & pendency
    "Total Cases Disposed Off by Police (Col.20=Col.8+ Col.9+ Col.16+ Col.19)": "disposed_total",
    "Cases Quashed at Investigation Stage (Col.21)": "quashed",
    "Cases Stayed at Investigation Stage (Col.22)": "stayed",
    "Cases Pending Investigation at End of the Year (Col.23=Col.7- Col.10- Col.20- Col.21)": "pending_end",

    # Rates
    "Chargesheeting Rate (Col.24=Col.19/ Col.20) *100": "chargesheet_rate_reported",
    "Pendency Percentage (Col.25=Col.23/ Col.7) *100": "pendency_pct_reported"
}
df18 = df18.rename(columns=ipc_2018_rename_map)
df18.head(2)
# Out:
#   S. No (Col.1)                   Category (Col.2)  \
# 0             1  Offences Affecting the Human Body
# 1             2  Offences Affecting the Human Body
#
#                                   crime_head  pending_prev  reported_year  \
# 0                                     Murder         20839          29017
# 1  Culpable Homicide not amounting to Murder          1745           3635
#
#    reopened  total_investigation_reported  not_investigated  transferred  \
# 0        35                         49891                 4          104
# 1         2                          5382                 0            6
#
#    withdrawn  ...  fr_total  chargesheet_prev  chargesheet_current  \
# 0          1  ...      4679              8679                16751
# 1          0  ...       626               943                 2002
#
#    chargesheet_total  disposed_total  quashed  stayed  pending_end  \
# 0              25430         30217.0        1      90        19672
# ...

# %%
violent_crimes_2018 = {
    "Murder": "Violent Crime",
    "Culpable Homicide not amounting to Murder": "Violent Crime",
    "Causing Death by Negligence": "Violent Crime",
    "Deaths due to Negligence relating to Road Accidents": "Violent Crime",
    "Hit and Run": "Violent Crime",
    "Other Accidents": "Violent Crime",
    "Deaths due to Negligence relating to Rail Accidents": "Violent Crime",
    "Deaths due to Medical Negligence": "Violent Crime",
    "Deaths due to Negligence of Civic Bodies": "Violent Crime",
    "Deaths due to other Negligence": "Violent Crime",
    "Abetment of Suicide": "Violent Crime",
    "Attempt to Commit Murder": "Violent Crime",
    "Attempt to commit Culpable Homicide": "Violent Crime",
    "Attempt to Commit Suicide": "Violent Crime",

    "Hurt": "Violent Crime",
    "Simple Hurt": "Violent Crime",
    "Voluntarily Causing Simple Hurt": "Violent Crime",
    "Voluntarily causing hurt by Dangerous weapons or means": "Violent Crime",
    "Voluntarily Causing hurt/Force to deter public servant from his duty": "Violent Crime",
    "Causing Hurt by act endangering life/safety of others": "Violent Crime",
    "Other Simple Hurt": "Violent Crime",

    "Grievous Hurt": "Violent Crime",
    "Voluntarily causing grievous hurt": "Violent Crime",
    "Voluntarily causing grievous hurt by dangerous weapons or means": "Violent Crime",
    "Voluntarily Causing Grievous hurt/Force to deter public servant from his duty": "Violent Crime",
    "Causing Grevious Hurt by act endangering life/safety of others": "Violent Crime",
    "Other Grevious Hurt": "Violent Crime",

    "Acid Attack": "Violent Crime",
    "Attempt to Acid Attack": "Violent Crime",
    "Wrongful Restraint/Confinement": "Violent Crime",
    "Unnatural Offences": "Violent Crime",
    "Offences Affecting the Human Body(Total)": "Violent Crime",
    "Causing Death by Negligence - Total": "Violent Crime",
    "Hurt - Total": "Violent Crime",
    "Causing Grievous Hurt by act endangering life/safety of others": "Violent Crime",
    "Other Grievous Hurt": "Violent Crime",
    "Offences Affecting the Human Body (Total)": "Violent Crime",
    "Kidnapping and Abduction - Total": "Violent Crime",
    "Kidnapping and Abduction": "Violent Crime",
    "Other Kidnapping & Abduction": "Violent Crime",
    "Kidnapping and Abduction for the Purpose of Begging": "Violent Crime",
    "Kidnapping and Abduction in order to Murder": "Violent Crime",
    "Kidnapping for Ransom": "Violent Crime"
}
crimes_against_women_2018 = {
    "Dowry Deaths": "Crime Against Women",
    "Assault on Women with Intent to Outrage her Modesty": "Crime Against Women",
    "Sexual Harassment": "Crime Against Women",
    "at Work or Office Premises": "Crime Against Women",
    "In Public Transport System": "Crime Against Women",
    "In Shelter Homes for women and Children": "Crime Against Women",
    "Other Places": "Crime Against Women",
    "Assault or use of Criminal Force on women with intent to Disrobe": "Crime Against Women",
    "Voyeurism": "Crime Against Women",
    "Stalking": "Crime Against Women",
    "Rape": "Crime Against Women",
    "Attempt to Commit Rape": "Crime Against Women",
    "Cruelty by Husband or his Relatives": "Crime Against Women",
    "Insult to the Modesty of Women": "Crime Against Women",
    "Kidnapping and Abduction of Women to compel her for marriage": "Crime Against Women"
}
crimes_against_children_2018 = {
    "Miscarriage, Infanticide, Foeticide and Abandonment": "Crime Against Children",
    "Missing Children Deemed as Kidnapped": "Crime Against Children",
    "Procuration of Minor Girls": "Crime Against Children",
    "Importation of Girls from Foreign Country": "Crime Against Children",
    "Selling of Minors for Prostitution": "Crime Against Children",
    "Buying of Minors for Prostitution": "Crime Against Children",
    "Assault on Women with Intent to Outrage her Modesty - Total": "Crime Against Women"
}
property_crimes_2018 = {
    "Theft": "Property Crime",
    "Auto/Motor Vehicle Theft": "Property Crime",
    "Other Thefts": "Property Crime",
    "Burglary": "Property Crime",
    "Day Time": "Property Crime",
    "Night": "Property Crime",
    "Extortion & Blackmailing": "Property Crime",
    "Robbery": "Property Crime",
    "Attempt to Commit Dacoity/Robbery": "Property Crime",
    "Dacoity": "Property Crime",
    "Dacoity with Murder": "Property Crime",
    "Making Preparation and Assembly for committing Dacoity": "Property Crime",
    "Criminal Misappropriation": "Property Crime",
    "Criminal Breach of Trust": "Property Crime",
    "Dishonestly Receiving/Dealing-in Stolen Property": "Property Crime",
    "Criminal Trespass": "Property Crime",
    "Arson": "Property Crime",
    "Offences against Property (Total)": "Property Crime",
    "Theft - Total": "Property Crime",
    "Burglary - Total": "Property Crime",
    "Dacoity - Total": "Property Crime",
    "Theft - Total": "Property Crime",
    "Burglary - Total": "Property Crime",
    "Dacoity - Total": "Property Crime"
}
economic_crimes_2018 = {
    "Counterfeiting": "Economic / Financial Crime",
    "Counterfeit Coin": "Economic / Financial Crime",
    "Counterfeiting Government Stamp": "Economic / Financial Crime",
    "Counterfeiting of Seal or Mark": "Economic / Financial Crime",
    "Counterfeit Currency & Bank notes": "Economic / Financial Crime",
    "Forgery, Cheating & Fraud": "Economic / Financial Crime",
    "Fraud": "Economic / Financial Crime",
    "Bank": "Economic / Financial Crime",
    "ATMs": "Economic / Financial Crime",
    "Credit Card/Debit Card": "Economic / Financial Crime",
    "Other Frauds": "Economic / Financial Crime",
    "Cheating": "Economic / Financial Crime",
    "Forgery": "Economic / Financial Crime",
    "Cheating by Impersonation": "Economic / Financial Crime",
    "Offences Relating to Documents & Property Marks (Total)": "Economic / Financial Crime",
    "Counterfeiting - Total": "Economic / Financial Crime",
    "Forgery, Cheating & Fraud - Total": "Economic / Financial Crime",
    "Counterfeiting - Total": "Economic / Financial Crime",
    "Forgery, Cheating & Fraud - Total": "Economic / Financial Crime",
    "Other Cheating": "Economic / Financial Crime",
    "Other Forgery": "Economic / Financial Crime"
}
public_order_state_crimes_2018 = {
    "Offences against State": "Public Order & State Crime",
    "Sedition": "Public Order & State Crime",
    "Offences against the State (Total)": "Public Order & State Crime",

    "Unlawful Assembly": "Public Order & State Crime",
    "Riots": "Public Order & State Crime",
    "Communal/Religious": "Public Order & State Crime",
    "Sectarian": "Public Order & State Crime",
    "Industrial": "Public Order & State Crime",
    "Political": "Public Order & State Crime",
    "Caste Conflict": "Public Order & State Crime",
    "Agrarian": "Public Order & State Crime",
    "Students": "Public Order & State Crime",
    "Money Dispute": "Public Order & State Crime",
    "Water Dispute": "Public Order & State Crime",
    "Land/Property Dispute": "Public Order & State Crime",
    "Family Disputes": "Public Order & State Crime",
    "Enmity/Rivalry": "Public Order & State Crime",
    "Electricity/Power Supply Disputes": "Public Order & State Crime",
    "Rioting while in Aandolan/Morcha": "Public Order & State Crime",
    "Rioting/Attacks on Police Personnel or Govt Servants": "Public Order & State Crime",
    "Other Riots": "Public Order & State Crime",

    "Offences promoting enmity between different groups": "Public Order & State Crime",
    "Promoting enmity between groups": "Public Order & State Crime",
    "Imputation, assertions prejudicial to national integration": "Public Order & State Crime",
    "Affray": "Public Order & State Crime",
    "Offences against Public Tranquillity (Total)": "Public Order & State Crime",

    "Offences relating to Elections": "Public Order & State Crime",
    "Disobedience to order duly promulgated by Public Servant": "Public Order & State Crime",
    "Harbouring an Offender": "Public Order & State Crime",
    "Offences relating to Religion": "Public Order & State Crime",
    "Offences against State - Total": "Public Order & State Crime",
    "Riots - Total": "Public Order & State Crime",
    "Offences promoting enmity between different groups - Total": "Public Order & State Crime",
    "Offences against State - Total": "Public Order & State Crime",
    "Riots - Total": "Public Order & State Crime",
    "Vigilants": "Public Order & State Crime",
    "Offences promoting enmity between different groups - Total": "Public Order & State Crime"
}
miscellaneous_crimes_2018 = {
    "Human Trafficking": "Miscellaneous / Other Crime",
    "Exploitation of Trafficked Person": "Miscellaneous / Other Crime",
    "Offences relating to Adulteration or Sale of Food/Drugs": "Miscellaneous / Other Crime",
    "Rash Driving on Public way": "Miscellaneous / Other Crime",
    "Rash Driving on Public Way": "Miscellaneous / Other Crime",
    "Causing Hurt by Rash/Negligent Driving on Public Way": "Miscellaneous / Other Crime",
    "Causing Grievous Hurt by Rash/Negligent Driving on Public": "Miscellaneous / Other Crime",
    "Obstruction on Public way": "Miscellaneous / Other Crime",
    "Sale of obscene Books/Objects": "Miscellaneous / Other Crime",
    "Obscene Acts and Songs at Public Places": "Miscellaneous / Other Crime",
    "Offences related to Mischief": "Miscellaneous / Other Crime",
    "Circulate False/Fake News/Rumours": "Miscellaneous / Other Crime",
    "Criminal Intimidation": "Miscellaneous / Other Crime",
    "Miscellaneous IPC Crimes(Total)": "Miscellaneous / Other Crime",
    "Other IPC crimes": "Miscellaneous / Other Crime",
    "Total Cognizable IPC crimes": "Miscellaneous / Other Crime",
    "Others": "Miscellaneous / Other Crime",
    "Rash Driving on Public way - Total": "Miscellaneous / Other Crime",
    "Rash Driving on Public way - Total": "Miscellaneous / Other Crime",
    "Miscellaneous IPC Crimes (Total)": "Miscellaneous / Other Crime",
    "Other IPC Crimes": "Miscellaneous / Other Crime",
    "Total Cognizable IPC Crimes": "Miscellaneous / Other Crime"
}

# %%
crime_type_map_2018 = {
    **violent_crimes_2018,
    **crimes_against_women_2018,
    **crimes_against_children_2018,
    **property_crimes_2018,
    **economic_crimes_2018,
    **public_order_state_crimes_2018,
    **miscellaneous_crimes_2018
}
df18["crime_type"] = df18["crime_head"].map(crime_type_map_2018)
df18.head(10)
# Out:
#   S. No (Col.1)                   Category (Col.2)  \
# 0             1  Offences Affecting the Human Body
# 1             2  Offences Affecting the Human Body
# 2             3  Offences Affecting the Human Body
# 3           3.1  Offences Affecting the Human Body
# 4         3.1.1  Offences Affecting the Human Body
# 5         3.1.2  Offences Affecting the Human Body
# 6           3.2  Offences Affecting the Human Body
# 7           3.3  Offences Affecting the Human Body
# 8           3.4  Offences Affecting the Human Body
# 9           3.5  Offences Affecting the Human Body
#
#                                           crime_head  pending_prev  \
# 0                                             Murder         20839
# 1          Culpable Homicide not amounting to Murder          1745
# 2                Causing Death by Negligence - Total         48536
# 3  Deaths due to Negligence relating to Road Acci...         43314
# ...

# %%
# df18[df18["crime_head"].map(crime_type_map).isna()]["crime_head"].unique()
df18[df18['crime_type'].isna()]
# Out:
# Empty DataFrame
# Columns: [S. No (Col.1), Category (Col.2), crime_head, pending_prev, reported_year, reopened, total_investigation_reported, not_investigated, transferred, withdrawn, fr_non_cognizable, fr_false, fr_mistake_civil, fr_untraced, fr_abated, fr_total, chargesheet_prev, chargesheet_current, chargesheet_total, disposed_total, quashed, stayed, pending_end, chargesheet_rate_reported, pendency_pct_reported, crime_type]
# Index: []
#
# [0 rows x 26 columns]

# %%
# df19=df19.drop(columns=['S. No']).reset_index(drop=True)
# df19['year']=2019

df19.head(2)
# df19.shape
# Out:
#   S. No                                 Crime Head  \
# 0     1                                     Murder
# 1     2  Culpable Homicide not amounting to Murder
#
#    Cases Pending Investigation from Previous Year  \
# 0                                           19589
# 1                                            1620
#
#    Cases Reported during the year  Cases Reopened for Investigation  \
# 0                           28918                                46
# 1                            3470                                14
#
#    Total Cases for Investigation (Col.3+ Col.4+ Col.5)  \
# 0                                              48553
# 1                                               5104
#
#    Cases Not Investigated Under 157_1_b CRPC  \
# 0                                          1
# 1                                          0
#
#    Cases Transferred to other State or Agency  \
# 0                                          94
# ...

# %%
ipc_2019_rename_map = {

    # Dimension
    "Crime Head": "crime_head",

    # Case inflow
    "Cases Pending Investigation from Previous Year": "pending_prev",
    "Cases Reported during the year": "reported_year",
    "Cases Reopened for Investigation": "reopened",
    "Total Cases for Investigation (Col.3+ Col.4+ Col.5)": "total_investigation_reported",

    # Investigation actions
    "Cases Not Investigated Under 157_1_b CRPC": "not_investigated",
    "Cases Transferred to other State or Agency": "transferred",
    "Cases Withdrawn by the Govt during investigation": "withdrawn",

    # Final report breakup
    "Final Report - Cases Ended as FR Non Cognizable": "fr_non_cognizable",
    "Final Report - Cases Ended as Final Report False": "fr_false",
    "Final Report - Cases Ended as Mistake of Fact or of Law or Civil Dispute": "fr_mistake_civil",
    "Final Report - Cases True but Insufficient Evidence or Untraced or No Clue": "fr_untraced",
    "Final Report - Cases Abated during Investigation": "fr_abated",
    "Final Report - Total": "fr_total",

    # Chargesheeting
    "Chargesheets submitted - Cases Chargesheeted Out of Cases from Previous Year": "chargesheet_prev",
    "Chargesheets submitted - Cases Chargesheeted Out of Cases during the Year": "chargesheet_current",
    "Chargesheets submitted - Cases Chargesheeted (Col.16+ Col.17)": "chargesheet_total",

    # Disposal & pendency
    "Total Cases Disposed Off by Police (Col.7+ Col.8+ Col.15+ Col.18)": "disposed_total",
    "Cases Quashed at Investigation Stage": "quashed",
    "Cases Stayed at Investigation Stage": "stayed",
    "Cases Pending Investigation at End of the Year (Col.6- Col.9- Col.19- Col.20)": "pending_end",

    # Rates
    "Charge-Sheeting Rate (Col.18/ Col.19) *100": "chargesheet_rate_reported",
    "Pendency Percentage (Col.22/ Col.6) *100": "pendency_pct_reported",

    # Year
    "year": "year"
}
df19 = df19.rename(columns=ipc_2019_rename_map)
df19.head(2)
# Out:
#   S. No                                 crime_head  pending_prev  \
# 0     1                                     Murder         19589
# 1     2  Culpable Homicide not amounting to Murder          1620
#
#    reported_year  reopened  total_investigation_reported  not_investigated  \
# 0          28918        46                         48553                 1
# 1           3470        14                          5104                 0
#
#    transferred  withdrawn  fr_non_cognizable  ...  \
# 0           94          0                  7  ...
# 1            1          0                  4  ...
#
#    Final Report - Total (Col.10+ Col.11+ Col.12+ Col.13+ Col.14)  \
# 0                                               3958
# 1                                                623
#
#    chargesheet_prev  chargesheet_current  chargesheet_total  disposed_total  \
# 0              7380                16183              23563           27616
# ...

# %%
def normalize_crime_head(s):
    return (
        s.strip()
         .replace("–", "-")
         .replace("—", "-")
         .replace("  ", " ")
    )
df19["crime_head"] = df19["crime_head"].apply(normalize_crime_head)
df19.head(2)
# Out:
#   S. No                                 crime_head  pending_prev  \
# 0     1                                     Murder         19589
# 1     2  Culpable Homicide not amounting to Murder          1620
#
#    reported_year  reopened  total_investigation_reported  not_investigated  \
# 0          28918        46                         48553                 1
# 1           3470        14                          5104                 0
#
#    transferred  withdrawn  fr_non_cognizable  ...  \
# 0           94          0                  7  ...
# 1            1          0                  4  ...
#
#    Final Report - Total (Col.10+ Col.11+ Col.12+ Col.13+ Col.14)  \
# 0                                               3958
# 1                                                623
#
#    chargesheet_prev  chargesheet_current  chargesheet_total  disposed_total  \
# 0              7380                16183              23563           27616
# ...

# %%
def categorize_crime(crime):
    c = crime.lower()

    # ───────────── Violent Crimes ─────────────
    if any(k in c for k in [
        "murder", "culpable homicide", "death by negligence",
        "abetment of suicide", "attempt to commit murder",
        "attempt to commit suicide", "hurt", "grievous hurt",
        "acid attack", "wrongful restraint", "unnatural offences",
        "offences affecting the human body"
    ]):
        return "Violent Crime"

    # ───────── Crimes Against Women ─────────
    if any(k in c for k in [
        "dowry deaths", "assault on women",
        "sexual harassment", "disrobe",
        "voyeurism", "stalking",
        "rape", "attempt to commit rape",
        "cruelty by husband",
        "insult to the modesty of women"
    ]):
        return "Crime Against Women"

    # ───────── Crimes Against Children ─────────
    if any(k in c for k in [
        "minor", "children", "infanticide",
        "foeticide", "abandonment",
        "procuration of minor",
        "importation of girls",
        "selling of minors",
        "buying of minors",
        "missing children"
    ]):
        return "Crime Against Children"

    # ───────── Kidnapping & Abduction ─────────
    if "kidnapping" in c or "abduction" in c:
        if "women" in c:
            return "Crime Against Women"
        return "Violent Crime"

    # ───────── Property Crimes ─────────
    if any(k in c for k in [
        "theft", "burglary", "robbery",
        "dacoity", "criminal misappropriation",
        "criminal breach of trust",
        "stolen property", "trespass", "arson"
    ]):
        return "Property Crime"

    # ───────── Economic / Financial Crimes ─────────
    if any(k in c for k in [
        "counterfeit", "forgery", "cheating",
        "fraud", "impersonation",
        "documents & property marks"
    ]):
        return "Economic / Financial Crime"

    # ───────── Public Order & State Crimes ─────────
    if any(k in c for k in [
        "offences against state", "sedition",
        "unlawful assembly", "riots",
        "communal", "sectarian", "political",
        "caste conflict", "agrarian", "students",
        "public tranquillity", "enmity",
        "national integration", "affray",
        "elections", "religion"
    ]):
        return "Public Order & State Crime"

    # ───────── Miscellaneous ─────────
    if any(k in c for k in [
        "rash driving", "obscene",
        "mischief", "fake news",
        "intimidation", "adulteration",
        "miscellaneous", "other ipc",
        "total cognizable"
    ]):
        return "Miscellaneous / Other Crime"

    return "Miscellaneous / Other Crime"
df19["crime_type"] = df19["crime_head"].apply(categorize_crime)
df19.head(10)
# Out:
#    S. No                                         crime_head  pending_prev  \
# 0      1                                             Murder         19589
# 1      2          Culpable Homicide not amounting to Murder          1620
# 2      3                        Causing Death by Negligence         47517
# 3    3.1  Deaths due to Negligence relating to Road Acci...         42405
# 4  3.1.1                                        Hit and Run         11021
# 5  3.1.2                                    Other Accidents         31384
# 6    3.2  Deaths due to Negligence relating to Rail Acci...            83
# 7    3.3                   Deaths due to Medical Negligence           158
# 8    3.4           Deaths due to Negligence of Civic Bodies            46
# 9    3.5                     Deaths due to other Negligence          4825
#
#    reported_year  reopened  total_investigation_reported  not_investigated  \
# 0          28918        46                         48553                 1
# ...

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 25 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   S. No                                                          142 non-null    object
#  1   crime_head                                                     142 non-null    object
#  2   pending_prev                                                   142 non-null    int64
#  3   reported_year                                                  142 non-null    int64
#  4   reopened                                                       142 non-null    int64
#  5   total_investigation_reported                                   142 non-null    int64
#  6   not_investigated                                               142 non-null    int64
# ...

# %%
df19["crime_type"].value_counts()
df19[df19['crime_type'].isna()]
# Out:
# Empty DataFrame
# Columns: [S. No, crime_head, pending_prev, reported_year, reopened, total_investigation_reported, not_investigated, transferred, withdrawn, fr_non_cognizable, fr_false, fr_mistake_civil, fr_untraced, fr_abated, Final Report - Total (Col.10+ Col.11+ Col.12+ Col.13+ Col.14), chargesheet_prev, chargesheet_current, chargesheet_total, disposed_total, quashed, stayed, pending_end, chargesheet_rate_reported, pendency_pct_reported, crime_type]
# Index: []
#
# [0 rows x 25 columns]

# %%
# df20=df20.drop(columns=['Si. No. (Col. 1)']).reset_index(drop=True)
# df20['year']=2020

df20.head(2)
# df20.shape
# Out:
#   Si. No. (Col. 1)                        Crime Head (Col. 2)  \
# 0                1                                     Murder
# 1                2  Culpable Homicide not amounting to Murder
#
#    Cases Pending Investigation from Previous Year - (Col. 3)  \
# 0                                              21023
# 1                                               1782
#
#    Cases Reported during the year - (Col. 4)  \
# 0                                      29193
# 1                                       3512
#
#    Cases Reopened for Investigation - (Col. 5)  \
# 0                                           42
# 1                                            4
#
#    Total Cases for Investi-gation (Col.3+ Col.4+ Col.5) - (Col. 6)  \
# 0                                              50258
# 1                                               5298
#
#    Cases Not Investigated Under 157_1_b CRPC - (Col. 7)  \
# 0                                                  4
# ...

# %%
ipc_2020_rename_map = {

    # Dimension
    "Crime Head (Col. 2)": "crime_head",

    # Case inflow
    "Cases Pending Investigation from Previous Year - (Col. 3)": "pending_prev",
    "Cases Reported during the year - (Col. 4)": "reported_year",
    "Cases Reopened for Investigation - (Col. 5)": "reopened",
    "Total Cases for Investi-gation (Col.3+ Col.4+ Col.5) - (Col. 6)": "total_investigation_reported",

    # Investigation actions
    "Cases Not Investigated Under 157_1_b CRPC - (Col. 7)": "not_investigated",
    "Cases Transferred to Other State or Agency - (Col. 8)": "transferred",
    "Cases Withdrawn by the Govt during Investigation - (Col. 9)": "withdrawn",

    # Final report breakup
    "Final Report - Cases Ended as FR Non Cognizable - (Col. 10)": "fr_non_cognizable",
    "Final Report - Cases Ended as Final Report False - (Col. 11)": "fr_false",
    "Final Report - Cases Ended as Mistake of Fact or of Law or Civil Dispute - (Col. 12)": "fr_mistake_civil",
    "Final Report - Cases True but Insufficient Evidence or Untraced or No Clue - (Col. 13)": "fr_untraced",
    "Final Report - Cases Abated during Investigation - (Col. 14)": "fr_abated",
    "Final Report - Total - (Col. 15)": "fr_total",

    # Chargesheeting
    "Charge Sheets Submitted - Cases Charge Sheeted Out of cases frm prv. Year - (Col. 16)": "chargesheet_prev",
    "Charge Sheets Submitted - Cases Chargesheeted Out of Cases during the year - (Col. 17)": "chargesheet_current",
    "Charge Sheets Submitted - Cases Chargesheeted (Col.16+ Col.17) - (Col. 18)": "chargesheet_total",

    # Disposal & pendency
    "Total Cases Disposed Off by Police (Col.7+8+15+18) - (Col. 19)": "disposed_total",
    "Cases Quashed at Investigation Stage - (Col. 20)": "quashed",
    "Cases Stayed at Investigation Stage - (Col. 21)": "stayed",
    "Cases Pending Invsgn.at end of the year (Cols. 6-9-19-20) - (Col. 22)": "pending_end",

    # Rates
    "Chargesheeting Rate (Col.18/19*100) - (Col. 23)": "chargesheet_rate_reported",
    "Pendency Percentage (Col.22/6*100) - (Col. 24)": "pendency_pct_reported",

    
}
df20 = df20.rename(columns=ipc_2020_rename_map)
df20.head(2)
# Out:
#   Si. No. (Col. 1)                                 crime_head  pending_prev  \
# 0                1                                     Murder         21023
# 1                2  Culpable Homicide not amounting to Murder          1782
#
#    reported_year  reopened  total_investigation_reported  not_investigated  \
# 0          29193        42                         50258                 4
# 1           3512         4                          5298                 0
#
#    transferred  withdrawn  fr_non_cognizable  ...  \
# 0           70          0                 18  ...
# 1            9          0                  3  ...
#
#    Final Report - Total (Col.10+ Col.11+ Col.12+ Col13+ Col.14) - (Col. 15)  \
# 0                                               4049
# 1                                                496
#
#    chargesheet_prev  chargesheet_current  chargesheet_total  disposed_total  \
# 0              7198                16817              24015           28138
# ...

# %%
def normalize_crime_head(s):
    return (
        s.strip()
         .replace("–", "-")
         .replace("—", "-")
         .replace("  ", " ")
    )

df20["crime_head"] = df20["crime_head"].apply(normalize_crime_head)
df20.head(2)
# Out:
#   Si. No. (Col. 1)                                 crime_head  pending_prev  \
# 0                1                                     Murder         21023
# 1                2  Culpable Homicide not amounting to Murder          1782
#
#    reported_year  reopened  total_investigation_reported  not_investigated  \
# 0          29193        42                         50258                 4
# 1           3512         4                          5298                 0
#
#    transferred  withdrawn  fr_non_cognizable  ...  \
# 0           70          0                 18  ...
# 1            9          0                  3  ...
#
#    Final Report - Total (Col.10+ Col.11+ Col.12+ Col13+ Col.14) - (Col. 15)  \
# 0                                               4049
# 1                                                496
#
#    chargesheet_prev  chargesheet_current  chargesheet_total  disposed_total  \
# 0              7198                16817              24015           28138
# ...

# %%
def categorize_crime(crime):
    c = crime.lower()

    # Violent Crime
    if any(k in c for k in [
        "murder", "culpable homicide", "death by negligence",
        "abetment of suicide", "attempt to commit murder",
        "attempt to commit suicide", "hurt", "grievous hurt",
        "acid attack", "wrongful restraint",
        "unnatural offences", "offences affecting the human body"
    ]):
        return "Violent Crime"

    # Crimes Against Women
    if any(k in c for k in [
        "dowry deaths", "assault on women",
        "sexual harassment", "disrobe",
        "voyeurism", "stalking",
        "rape", "attempt to commit rape",
        "cruelty by husband",
        "insult to the modesty of women"
    ]):
        return "Crime Against Women"

    # Crimes Against Children
    if any(k in c for k in [
        "minor", "children", "infanticide",
        "foeticide", "abandonment",
        "procuration of minor",
        "importation of girls",
        "selling of minors",
        "buying of minors",
        "missing children"
    ]):
        return "Crime Against Children"

    # Kidnapping & Abduction
    if "kidnapping" in c or "abduction" in c:
        if "women" in c:
            return "Crime Against Women"
        return "Violent Crime"

    # Property Crime
    if any(k in c for k in [
        "theft", "burglary", "robbery",
        "dacoity", "criminal misappropriation",
        "criminal breach of trust",
        "stolen property", "trespass", "arson"
    ]):
        return "Property Crime"

    # Economic / Financial Crime
    if any(k in c for k in [
        "counterfeit", "forgery", "cheating",
        "fraud", "impersonation",
        "documents & property marks"
    ]):
        return "Economic / Financial Crime"

    # Public Order & State Crime
    if any(k in c for k in [
        "offences against state", "sedition",
        "unlawful assembly", "riots",
        "communal", "sectarian", "political",
        "caste conflict", "agrarian", "students",
        "public tranquillity", "enmity",
        "national integration", "affray",
        "elections", "religion"
    ]):
        return "Public Order & State Crime"

    # Miscellaneous / Other Crime
    if any(k in c for k in [
        "rash driving", "obscene",
        "mischief", "fake news",
        "intimidation", "adulteration",
        "miscellaneous", "other ipc",
        "total cognizable"
    ]):
        return "Miscellaneous / Other Crime"

    return "Miscellaneous / Other Crime"
df20["crime_type"] = df20["crime_head"].apply(categorize_crime)
df20.head(10)
# Out:
#   Si. No. (Col. 1)                                         crime_head  \
# 0                1                                             Murder
# 1                2          Culpable Homicide not amounting to Murder
# 2                3                        Causing Death by Negligence
# 3              3.1  Deaths due to Negligence relating to Road Acci...
# 4            3.1.1                                        Hit and Run
# 5            3.1.2                                    Other Accidents
# 6              3.2  Deaths due to Negligence relating to Rail Acci...
# 7              3.3                   Deaths due to Medical Negligence
# 8              3.4           Deaths due to Negligence of Civic Bodies
# 9              3.5                     Deaths due to other Negligence
#
#    pending_prev  reported_year  reopened  total_investigation_reported  \
# 0         21023          29193        42                         50258
# ...

# %%
df20[df20["crime_type"].isna()]["crime_head"].unique()
# Out:
# array([], dtype=object)

# %%
# df21=df21.drop(columns=['Sl. No. Col. (1)']).reset_index(drop=True)
# df21['year']=2021

df21.head(2)
# df21.shape
# Out:
#   Sl. No. Col. (1)                        Crime Head Col. (2)  \
# 0                1                                     Murder
# 1                2  Culpable Homicide not amounting to Murder
#
#    Cases Pending Investigation from Previous Year - Col. (3)  \
# 0                                              22198
# 1                                               1810
#
#    Cases Reported during the year - Col. (4)  \
# 0                                      29272
# 1                                       3807
#
#    Cases Reopened for Investigation - Col. (5)  \
# 0                                           70
# 1                                           33
#
#    Total Cases for Investigation (Col.3+Col.4+Col.5) - Col. (6)  \
# 0                                              51540
# 1                                               5650
#
#    Cases Not Investigated Under 157_1_b CRPC - Col. (7)  \
# 0                                                  3
# ...

# %%
ipc_2021_rename_map = {

    # Identifiers
    "Sl. No. Col. (1)": "s_no",
    "Crime Head Col. (2)": "crime_head",

    # Case inflow
    "Cases Pending Investigation from Previous Year - Col. (3)": "pending_prev",
    "Cases Reported during the year - Col. (4)": "reported_year",
    "Cases Reopened for Investigation - Col. (5)": "reopened",
    "Total Cases for Investigation (Col.3+Col.4+Col.5) - Col. (6)": "total_investigation_reported",

    # Investigation actions
    "Cases Not Investigated Under 157_1_b CRPC - Col. (7)": "not_investigated",
    "Cases Transferred to Other State or Agency - Col. (8)": "transferred",
    "Cases Withdrawn by the Govt during Investigation - Col. (9)": "withdrawn",

    # Final report breakup
    "Final Report - Cases Ended as FR Non Cognizable - Col. (10)": "fr_non_cognizable",
    "Final Report - Cases Ended as Final Report False - Col. (11)": "fr_false",
    "Final Report - Cases Ended as Mistake of Fact or of Law or Civil Dispute - Col. (12)": "fr_mistake_civil",
    "Final Report - Cases True but Insufficient Evidence or Untraced or No Clue - Col. (13)": "fr_untraced",
    "Final Report - Cases Abated during Investigation - Col. (14)": "fr_abated",
    "Final Report - Total (Col.10+Col.11+Col.12+Col13+Col.14) - Col. (15)": "fr_total",

    # Chargesheeting
    "Charge Sheets Submitted - Cases ChargeSheeted Out of cases From Prev. Year - Col. (16)": "chargesheet_prev",
    "Charge Sheets Submitted - Cases Charge sheeted Out of Cases during the year - Col. (17)": "chargesheet_current",
    "Charge Sheets Submitted - Cases Charge sheeted (Col.16+Col.17) - Col. (18)": "chargesheet_total",

    # Disposal & pendency
    "Total Cases Disposed Off by Police (Col.7+8+15+18) - Col. (19)": "disposed_total",
    "Cases Quashed at Investigation Stage - Col. (20)": "quashed",
    "Cases Stayed at Investigation Stage - Col. (21)": "stayed",
    "Cases Pending Invsgn.at end of the year (Col.6-9-19-20) - Col. (22)": "pending_end",

    # Rates
    "Chargesheeting Rate (Col.18/19*100) - Col. (23)": "chargesheet_rate_reported",
    "Pendency Percentage (Col.22/6*100) - Col. (24)": "pendency_pct_reported"
}
df21 = df21.rename(columns=ipc_2021_rename_map)
df21.head(2)
# Out:
#   s_no                                 crime_head  pending_prev  \
# 0    1                                     Murder         22198
# 1    2  Culpable Homicide not amounting to Murder          1810
#
#    reported_year  reopened  total_investigation_reported  not_investigated  \
# 0          29272        70                         51540                 3
# 1           3807        33                          5650                 0
#
#    transferred  withdrawn  fr_non_cognizable  ...  fr_total  chargesheet_prev  \
# 0           81          0                  6  ...      5010              8831
# 1            5          0                  1  ...       485              1014
#
#    chargesheet_current  chargesheet_total  disposed_total  quashed  stayed  \
# 0                17551              26382           31476        0     154
# 1                 2333               3347            3837        3       9
#
#    pending_end  chargesheet_rate_reported  pendency_pct_reported
# ...

# %%
def normalize_crime_head(s):
    return (
        s.strip()
         .replace("–", "-")
         .replace("—", "-")
         .replace("  ", " ")
    )

df21["crime_head"] = df21["crime_head"].apply(normalize_crime_head)

# %%
def categorize_crime(crime):
    c = crime.lower()

    # ───────── Violent Crime ─────────
    if any(k in c for k in [
        "murder", "culpable homicide",
        "death by negligence",
        "abetment of suicide",
        "attempt to commit murder",
        "attempt to commit suicide",
        "hurt", "grievous hurt",
        "acid attack",
        "wrongful restraint",
        "unnatural offences",
        "offences affecting the human body"
    ]):
        return "Violent Crime"

    # ───────── Crime Against Women ─────────
    if any(k in c for k in [
        "dowry deaths",
        "assault on women",
        "sexual harassment",
        "disrobe",
        "voyeurism",
        "stalking",
        "rape",
        "attempt to commit rape",
        "cruelty by husband",
        "insult to the modesty of women"
    ]):
        return "Crime Against Women"

    # ───────── Crime Against Children ─────────
    if any(k in c for k in [
        "minor",
        "children",
        "infanticide",
        "foeticide",
        "abandonment",
        "procuration of minor",
        "importation of girls",
        "selling of minors",
        "buying of minors",
        "missing children"
    ]):
        return "Crime Against Children"

    # ───────── Kidnapping & Abduction ─────────
    if "kidnapping" in c or "abduction" in c:
        if "women" in c:
            return "Crime Against Women"
        return "Violent Crime"

    # ───────── Property Crime ─────────
    if any(k in c for k in [
        "theft",
        "burglary",
        "robbery",
        "dacoity",
        "criminal misappropriation",
        "criminal breach of trust",
        "stolen property",
        "trespass",
        "arson"
    ]):
        return "Property Crime"

    # ───────── Economic / Financial Crime ─────────
    if any(k in c for k in [
        "counterfeit",
        "forgery",
        "cheating",
        "fraud",
        "impersonation",
        "documents & property marks"
    ]):
        return "Economic / Financial Crime"

    # ───────── Public Order & State Crime ─────────
    if any(k in c for k in [
        "offences against state",
        "sedition",
        "unlawful assembly",
        "riots",
        "communal",
        "sectarian",
        "political",
        "caste conflict",
        "agrarian",
        "students",
        "public tranquillity",
        "enmity",
        "national integration",
        "affray",
        "elections",
        "religion"
    ]):
        return "Public Order & State Crime"

    # ───────── Miscellaneous / Other Crime ─────────
    if any(k in c for k in [
        "rash driving",
        "obscene",
        "mischief",
        "fake news",
        "intimidation",
        "adulteration",
        "miscellaneous",
        "other ipc",
        "total cognizable"
    ]):
        return "Miscellaneous / Other Crime"

    return "Miscellaneous / Other Crime"
df21["crime_type"] = df21["crime_head"].apply(categorize_crime)
df21.tail(20)
# Out:
#                                 s_no  \
# 122                               41
# 123                               42
# 124                             42.1
# 125                             42.2
# 126                             42.3
# 127                               43
# 128                               44
# 129                               45
# 130                               46
# 131                               47
# 132                               48
# 133                               49
# 134                               50
# 135                               51
# 136                               52
# 137                               53
# 138                               54
# 139  Miscellaneous IPC Crimes(Total)
# 140                               55
# 141      Total Cognizable IPC crimes
#
#                                             crime_head  pending_prev  \
# 122  Offences relating to Adulteration or Sale of F...          2381
# ...

# %%
df17.to_excel("ipc_crimes_2017_clean.xlsx", index=False)
df18.to_excel("ipc_crimes_2018_clean.xlsx", index=False)
df19.to_excel("ipc_crimes_2019_clean.xlsx", index=False)
df20.to_excel("ipc_crimes_2020_clean.xlsx", index=False)
df21.to_excel("ipc_crimes_2021_clean.xlsx", index=False)
